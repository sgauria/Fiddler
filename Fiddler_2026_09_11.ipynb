# %% [markdown]
# # Puzzle
#
# https://thefiddler.substack.com/p/can-you-cheat-on-the-quiz

# %% [markdown]
# # Solution
#
# https://docs.google.com/spreadsheets/d/12ksSfdqasSJUTP-F6VHKU5rLjKzh8cPjrirXPz3QTuk/edit?usp=sharing
