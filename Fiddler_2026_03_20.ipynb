# %% [markdown]
# # Puzzle
#
# https://thefiddler.substack.com/p/can-you-trace-the-locus
#
# You wrap a string around a circle (or two) and pull the string taut. What is the area of the resulting region you can trace out?

# %% [markdown]
# # Fiddler Solution
#
# https://www.desmos.com/calculator/ljlvenizqp
#
# (a ~= 0.305313055395)
#
# Fiddler Answer = Area is approx 33.7022675396.
